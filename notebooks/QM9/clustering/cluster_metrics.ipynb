# %%
import os
os.chdir('../../..')

# %%
import json
import pandas as pd
import plotly.graph_objects as go

from pathlib import Path
from IPython.display import display, Markdown
from plotly.subplots import make_subplots

# %%
report_path = Path('results/cluster_reports/consolidated_report.json')
with report_path.open() as f:
    report_data = json.load(f)

cluster_score_keys = sorted(
    k for k in report_data.keys() if k.endswith('cluster_scores.json')
)

isomer_non_euclidean_keys = [
    k for k in cluster_score_keys if 'isomers_non_euclidean' in k
]
isomer_euclidean_keys = [
    k for k in cluster_score_keys if 'isomers_euclidean' in k
]
other_keys = [
    k for k in cluster_score_keys
    if k not in isomer_non_euclidean_keys and k not in isomer_euclidean_keys
]

len(cluster_score_keys)
# Out:
# 32

# %%
def _title_from_key(key: str) -> str:
    # e.g. non_euclidean/wasserstein_cluster_scores.json -> non_euclidean/wasserstein
    return key.replace('_cluster_scores.json', '')


def _display_scores(keys, section_title=None):
    if section_title:
        display(Markdown(f"# {section_title}"))

    if not keys:
        display(Markdown("No entries found."))
        return

    for key in keys:
        payload = report_data.get(key, {})
        title = _title_from_key(key)

        display(Markdown(f"## {title}"))

        summary = {
            "embedding": payload.get("embedding"),
            "best_k_used": payload.get("best_k_used"),
            "valid_count": payload.get("valid_count"),
            "total_count": payload.get("total_count"),
        }
        display(pd.DataFrame([summary]))

        congruence = payload.get("congruence")
        if isinstance(congruence, dict) and len(congruence) > 0:
            df_congruence = (
                pd.DataFrame(
                    [{"cluster": str(k), "congruence": v} for k, v in congruence.items()]
                )
                .sort_values("cluster")
                .reset_index(drop=True)
            )
            display(Markdown("**Congruence**"))
            display(df_congruence)
        else:
            display(Markdown("**Congruence**: not available"))

        mcs = payload.get("molecular_cluster_score")
        if isinstance(mcs, dict) and len(mcs) > 0:
            if "error" in mcs:
                display(Markdown(f"**Molecular Cluster Score**: {mcs['error']}"))
            else:
                df_mcs = pd.DataFrame([mcs])
                display(Markdown("**Molecular Cluster Score**"))
                display(df_mcs)
        else:
            display(Markdown("**Molecular Cluster Score**: not available"))


_display_scores(isomer_non_euclidean_keys, section_title="Isomer Non-Euclidean")
_display_scores(isomer_euclidean_keys, section_title="Isomer Euclidean")
_display_scores(other_keys, section_title="All Other Cluster Scores")
# Out:
# # Isomer Non-Euclidean
# ## isomers_non_euclidean/affine_riemann_formula_C6H10O
#             embedding  best_k_used  valid_count  total_count
# 0  affine_riemann_mds            2           87           87
# **Congruence**
#   cluster  congruence
# 0       0    0.620932
# 1       1    0.668771
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.495767          0.82716        0.054431        0.473906
#
#    separation_score  structure_class_score
# 0           0.53793               0.818182
# ## isomers_non_euclidean/euclidean_riemann_formula_C6H10O
#                embedding  best_k_used  valid_count  total_count
# 0  euclidean_riemann_mds            2           87           87
# **Congruence**
#   cluster  congruence
# 0       0    0.621572
# 1       1    0.684683
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.500997         0.845218        0.046092        0.464646
#
#    separation_score  structure_class_score
# 0          0.561528               0.818182
# ## isomers_non_euclidean/grassmann_formula_C6H10O
#        embedding  best_k_used  valid_count  total_count
# 0  grassmann_mds            2           87           87
# **Congruence**
#   cluster  congruence
# 0       0    0.771755
# 1       1    0.755018
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.682665           0.9242        0.384033        0.662582
#
#    separation_score  structure_class_score
# 0          0.652591               0.773693
# ## isomers_non_euclidean/wasserstein_formula_C6H10O
#          embedding  best_k_used  valid_count  total_count
# 0  wasserstein_mds           14           87           87
# **Congruence**
#    cluster  congruence
# 0        0    0.705274
# 1        1    0.800556
# 2       10    0.725523
# 3       11    0.772109
# 4       12    0.585144
# 5       13    0.677633
# 6        2    0.538283
# 7        3    0.548463
# 8        4    0.525815
# 9        5    0.601990
# 10       6    0.591177
# 11       7    0.974120
# 12       8    0.711856
# 13       9    0.666597
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.341649         0.270447        0.296795        0.648073
#
#    separation_score  structure_class_score
# 0          0.148166                0.84966
# # Isomer Euclidean
# ## isomers_euclidean/acsf_embedding_formula_C6H10O
#         embedding  best_k_used  valid_count  total_count
# 0  acsf_embedding           14           87           87
# **Congruence**
#    cluster  congruence
# 0        0    0.948444
# 1        1    0.934991
# 2       10    0.969861
# 3       11    0.985159
# 4       12    0.936123
# 5       13    0.959072
# 6        2    0.915492
# 7        3    0.959990
# 8        4    0.929178
# 9        5    0.818905
# 10       6    0.888700
# 11       7    0.950744
# 12       8    0.978126
# 13       9    0.975729
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.804162         0.698918        0.933647        0.982143
#
#    separation_score  structure_class_score
# 0          0.480723               0.982143
# ## isomers_euclidean/chemprop_embedding_formula_C6H10O
#             embedding  best_k_used  valid_count  total_count
# 0  chemprop_embedding            3           87           87
# **Congruence**
#   cluster  congruence
# 0       0    0.633307
# 1       1    0.795892
# 2       2    0.795081
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.500526         0.795927         0.08478        0.541126
#
#    separation_score  structure_class_score
# 0          0.484962                    1.0
# ## isomers_euclidean/morgan_fingerprint_formula_C6H10O
#             embedding  best_k_used  valid_count  total_count
# 0  morgan_fingerprint            2           87           87
# **Congruence**
#   cluster  congruence
# 0       0    0.566743
# 1       1    0.672245
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0      0.40278         0.609591        0.039379        0.584416
#
#    separation_score  structure_class_score
# 0          0.302468                    1.0
# ## isomers_euclidean/selfies_transformer_formula_C6H10O
#              embedding  best_k_used  valid_count  total_count
# 0  selfies_transformer            2           87           87
# **Congruence**
#   cluster  congruence
# 0       0    0.711051
# 1       1    0.789138
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.451682         0.700472        0.039379        0.584416
#
#    separation_score  structure_class_score
# 0          0.427959                    1.0
# ## isomers_euclidean/soap_embedding_formula_C6H10O
#         embedding  best_k_used  valid_count  total_count
# 0  soap_embedding            2           87           87
# **Congruence**
#   cluster  congruence
# 0       0    0.711456
# 1       1    0.763915
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.496252         0.837552               0        0.521361
#
#    separation_score  structure_class_score
# 0          0.569588               0.917722
# # All Other Cluster Scores
# ## descriptors_kmeans/acsf_embedding
#         embedding  best_k_used  valid_count  total_count
# 0  acsf_embedding            2         2000         2000
# **Congruence**
#   cluster  congruence
# 0       0    0.453801
# 1       1    0.600246
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.419719         0.664335        0.172863        0.252198
#
#    separation_score  structure_class_score
# 0          0.516867               0.536569
# ## descriptors_kmeans/chemprop_embedding
#             embedding  best_k_used  valid_count  total_count
# 0  chemprop_embedding            2         2000         2000
# **Congruence**
#   cluster  congruence
# 0       0    0.596196
# 1       1    0.525146
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.484884         0.804831        0.124772        0.344858
#
#    separation_score  structure_class_score
# 0          0.565487               0.756449
# ## descriptors_kmeans/coulomb_matrix
#         embedding  best_k_used  valid_count  total_count
# 0  coulomb_matrix            2         2000         2000
# **Congruence**
#   cluster  congruence
# 0       0    0.526934
# 1       1    0.551591
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.417074         0.700244        0.151119        0.276212
#
#    separation_score  structure_class_score
# 0          0.363984               0.448152
# ## descriptors_kmeans/morgan_fingerprint
#             embedding  best_k_used  valid_count  total_count
# 0  morgan_fingerprint            2         2000         2000
# **Congruence**
#   cluster  congruence
# 0       0    0.281673
# 1       1    0.349350
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.320152         0.544843        0.100878        0.264677
#
#    separation_score  structure_class_score
# 0          0.190157               0.545545
# ## descriptors_kmeans/selfies_onehot
#         embedding  best_k_used  valid_count  total_count
# 0  selfies_onehot            2         2000         2000
# **Congruence**
#   cluster  congruence
# 0       0    0.352001
# 1       1    0.508887
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.380888         0.603107        0.210519        0.253959
#
#    separation_score  structure_class_score
# 0           0.25698               0.527596
# ## descriptors_kmeans/selfies_transformer
#              embedding  best_k_used  valid_count  total_count
# 0  selfies_transformer            2         2000         2000
# **Congruence**
#   cluster  congruence
# 0       0    0.398458
# 1       1    0.566762
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.361371         0.645409        0.075733        0.249332
#
#    separation_score  structure_class_score
# 0          0.306208               0.435116
# ## descriptors_kmeans/soap_embedding
#         embedding  best_k_used  valid_count  total_count
# 0  soap_embedding            2         2000         2000
# **Congruence**
#   cluster  congruence
# 0       0    0.426084
# 1       1    0.609484
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.419638         0.643247        0.205472        0.254442
#
#    separation_score  structure_class_score
# 0          0.498095               0.543277
# ## euclidean_metrics/acsf_embedding
#         embedding  best_k_used  valid_count  total_count
# 0  acsf_embedding            2         2000         2000
# **Congruence**
#   cluster  congruence
# 0       0    0.231761
# 1       1    0.684087
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.479541         0.521866        0.363016        0.526566
#
#    separation_score  structure_class_score
# 0          0.565762                0.72782
# ## euclidean_metrics/chemprop_embedding
#             embedding  best_k_used  valid_count  total_count
# 0  chemprop_embedding            2         2000         2000
# **Congruence**
#   cluster  congruence
# 0       0    0.872765
# 1       1    0.532651
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.602673         0.880986        0.252551        0.625689
#
#    separation_score  structure_class_score
# 0          0.493758               0.727591
# ## euclidean_metrics/morgan_fingerprint
#             embedding  best_k_used  valid_count  total_count
# 0  morgan_fingerprint            2         2000         2000
# **Congruence**
#   cluster  congruence
# 0       0    0.334725
# 1       1    0.666667
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0      0.38259         0.560313        0.005398        0.626063
#
#    separation_score  structure_class_score
# 0          0.316327               0.727364
# ## euclidean_metrics/selfies_transformer
#              embedding  best_k_used  valid_count  total_count
# 0  selfies_transformer            2         2000         2000
# **Congruence**
#   cluster  congruence
# 0       0    0.760125
# 1       1    0.513875
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.529085         0.752601        0.284309        0.518412
#
#    separation_score  structure_class_score
# 0          0.390692                0.72943
# ## euclidean_metrics/soap_embedding
#         embedding  best_k_used  valid_count  total_count
# 0  soap_embedding            2         2000         2000
# **Congruence**
#   cluster  congruence
# 0       0    0.523452
# 1       1    0.570224
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.399283         0.685394        0.124883         0.25652
#
#    separation_score  structure_class_score
# 0          0.363563               0.490593
# ## isomers/acsf_embedding_formula_C6H10O
#         embedding  best_k_used  valid_count  total_count
# 0  acsf_embedding            2           87           87
# **Congruence**
#   cluster  congruence
# 0       0    0.746500
# 1       1    0.717981
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.453722         0.741735        0.023794        0.470539
#
#    separation_score  structure_class_score
# 0          0.557815               0.818182
# ## isomers/chemprop_embedding_formula_C6H10O
#             embedding  best_k_used  valid_count  total_count
# 0  chemprop_embedding            2           87           87
# **Congruence**
#   cluster  congruence
# 0       0    0.714808
# 1       1    0.797282
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.485959         0.716925        0.113678        0.534512
#
#    separation_score  structure_class_score
# 0          0.581831               0.805556
# ## isomers/coulomb_matrix_formula_C6H10O
#         embedding  best_k_used  valid_count  total_count
# 0  coulomb_matrix           14           87           87
# **Congruence**
#    cluster  congruence
# 0        0    0.842985
# 1        1    0.749532
# 2       10    0.982060
# 3       11    0.876729
# 4       12    0.773748
# 5       13    0.672615
# 6        2    0.684370
# 7        3    0.765805
# 8        4    0.768955
# 9        5    0.971413
# 10       6    0.721584
# 11       7    0.775139
# 12       8    0.974359
# 13       9    0.955316
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.612702         0.607481        0.611748        0.738039
#
#    separation_score  structure_class_score
# 0          0.385776                0.85119
# ## isomers/morgan_fingerprint_formula_C6H10O
#             embedding  best_k_used  valid_count  total_count
# 0  morgan_fingerprint            3           87           87
# **Congruence**
#   cluster  congruence
# 0       0    0.635205
# 1       1    0.574676
# 2       2    0.672245
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.395458         0.582765        0.085982        0.551429
#
#    separation_score  structure_class_score
# 0          0.262722                    1.0
# ## isomers/selfies_onehot_formula_C6H10O
#         embedding  best_k_used  valid_count  total_count
# 0  selfies_onehot            3           87           87
# **Congruence**
#   cluster  congruence
# 0       0    0.690107
# 1       1    0.648118
# 2       2    0.737887
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.413853         0.629364        0.063043         0.55641
#
#    separation_score  structure_class_score
# 0          0.319124               0.966667
# ## isomers/selfies_transformer_formula_C6H10O
#              embedding  best_k_used  valid_count  total_count
# 0  selfies_transformer            3           87           87
# **Congruence**
#   cluster  congruence
# 0       0    0.684589
# 1       1    0.761540
# 2       2    0.789137
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.468213          0.70139        0.123982        0.553571
#
#    separation_score  structure_class_score
# 0          0.397486                    1.0
# ## isomers/soap_embedding_formula_C6H10O
#         embedding  best_k_used  valid_count  total_count
# 0  soap_embedding            2           87           87
# **Congruence**
#   cluster  congruence
# 0       0    0.750091
# 1       1    0.718313
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.449837         0.737987        0.030389        0.481687
#
#    separation_score  structure_class_score
# 0          0.491876               0.784684
# ## non_euclidean/affine_riemann
#             embedding  best_k_used  valid_count  total_count
# 0  affine_riemann_mds            2         2000         2000
# **Congruence**
#   cluster  congruence
# 0       0    0.277978
# 1       1    0.913171
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.547134         0.646077        0.320331        0.587353
#
#    separation_score  structure_class_score
# 0          0.751336               0.532248
# ## non_euclidean/euclidean_riemann
#                embedding  best_k_used  valid_count  total_count
# 0  euclidean_riemann_mds            2         2000         2000
# **Congruence**
#   cluster  congruence
# 0       0    0.252039
# 1       1    0.778486
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.500991         0.591471        0.234472        0.590165
#
#    separation_score  structure_class_score
# 0           0.76028               0.528275
# ## non_euclidean/grassmann
#        embedding  best_k_used  valid_count  total_count
# 0  grassmann_mds            5         2000         2000
# **Congruence**
#   cluster  congruence
# 0       0    0.539504
# 1       1    0.527285
# 2       2    0.634666
# 3       3    0.490040
# 4       4    0.527093
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.448447         0.677874        0.148114        0.357394
#
#    separation_score  structure_class_score
# 0          0.613838                0.48066
# ## non_euclidean/wasserstein
#          embedding  best_k_used  valid_count  total_count
# 0  wasserstein_mds            2         2000         2000
# **Congruence**
#   cluster  congruence
# 0       0    0.341419
# 1       1    0.353666
# **Molecular Cluster Score**
#    total_score  structure_score  property_score  category_score  \
# 0     0.330208          0.61751        0.002145        0.252152
#
#    separation_score  structure_class_score
# 0          0.321304               0.447718

# %%
def plot_all_categories(report_data, categories=None):
    rows = []
    metrics = ['structure_score', 'property_score', 'category_score', 'separation_score', 'structure_class_score']
    
    for key, payload in report_data.items():
        if '/' not in key:
            continue
            
        parts = key.split('/')
        if len(parts) < 2:
            continue
            
        category = parts[0]
        method = parts[1].replace('_cluster_scores.json', '')

        # Filter categories if provided
        if categories is not None and category not in categories:
            continue

        mcs = payload.get("molecular_cluster_score", {})
        
        if isinstance(mcs, dict) and all(m in mcs for m in metrics):
            row = {"category": category, "method": method}
            for m in metrics:
                row[m] = mcs.get(m, 0)
            rows.append(row)

    if not rows:
        print("No valid cluster scores found for the selected categories.")
        return

    df = pd.DataFrame(rows)

    # If categories not provided, infer from dataframe
    if categories is None:
        categories = df['category'].unique()
    else:
        categories = [c for c in categories if c in df['category'].unique()]

    fig = make_subplots(
        rows=len(categories), cols=1,
        specs=[[{'type': 'polar'}] for _ in categories],
        subplot_titles=[f"Category: {c}" for c in categories],
        vertical_spacing=0.05
    )

    colors = ['#636EFA', '#EF553B', '#00CC96', '#AB63FA', '#FFA15A',
              '#19D3AF', '#FF6692', '#B6E880']

    for i, cat in enumerate(categories):
        cat_df = df[df['category'] == cat]

        for j, (_, row) in enumerate(cat_df.iterrows()):
            values = [row[m] for m in metrics]
            values.append(values[0])

            fig.add_trace(
                go.Scatterpolar(
                    r=values,
                    theta=metrics + [metrics[0]],
                    name=row['method'],
                    legendgroup=cat,
                    line=dict(color=colors[j % len(colors)])
                ),
                row=i+1, col=1
            )

    fig.update_layout(
        height=500 * len(categories),
        template="plotly_dark",
        showlegend=True,
        margin=dict(t=100, b=50, l=100, r=100),
        legend=dict(groupclick="toggleitem")
    )
    
    fig.update_polars(radialaxis=dict(visible=True, range=[0, 1]))
    fig.show()

# %%
plot_all_categories(report_data, categories=['isomers', 'isomers_euclidean'])

# %%
plot_all_categories(report_data, categories=['descriptors_kmeans', 'euclidean_metrics'])

# %%
plot_all_categories(report_data, categories = ['non_euclidean', 'isomers_non_euclidean'])
